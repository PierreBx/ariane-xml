# %%
;

# %%
SELECT .name FROM examples/test.xml;
# Out:
# name
# ---------------------------
# Belgian Waffles
# Strawberry Belgian Waffles
# Berry-Berry Belgian Waffles
# French Toast
# Homestyle Breakfast
#
# 5 rows returned.

# %%
SELECT .SELECT .name FROM examples/test.xml;FROM examples/test.xml;
